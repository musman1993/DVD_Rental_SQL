# %% [markdown]
# # PostgreSQL Northwind Database - Polar and SQL Learning
#
# Query and explore the North database using Polars and SQL.

# %%
import polars as pl

# %%
uri_north = "postgresql://neondb_owner:npg_X9yglTDSNqI7@ep-fancy-morning-ayjb5nrr-pooler.c-5.us-east-2.aws.neon.tech/neondb?sslmode=require&channel_binding=require"
query = "SELECT * FROM orders"

read_north = pl.read_database_uri(query=query, uri=uri_north)
read_north
# Out:
# shape: (830, 14)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ order_id ┆ customer_ ┆ employee_ ┆ order_dat ┆ … ┆ ship_city ┆ ship_regi ┆ ship_post ┆ ship_coun │
# │ ---      ┆ id        ┆ id        ┆ e         ┆   ┆ ---       ┆ on        ┆ al_code   ┆ try       │
# │ i16      ┆ ---       ┆ ---       ┆ ---       ┆   ┆ str       ┆ ---       ┆ ---       ┆ ---       │
# │          ┆ str       ┆ i16       ┆ date      ┆   ┆           ┆ str       ┆ str       ┆ str       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 10248    ┆ VINET     ┆ 5         ┆ 1996-07-0 ┆ … ┆ Reims     ┆ null      ┆ 51100     ┆ France    │
# │          ┆           ┆           ┆ 4         ┆   ┆           ┆           ┆           ┆           │
# │ 10249    ┆ TOMSP     ┆ 6         ┆ 1996-07-0 ┆ … ┆ Münster   ┆ null      ┆ 44087     ┆ Germany   │
# ...

# %%
query="select * from products"
read_north
# Out:
# shape: (830, 14)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ order_id ┆ customer_ ┆ employee_ ┆ order_dat ┆ … ┆ ship_city ┆ ship_regi ┆ ship_post ┆ ship_coun │
# │ ---      ┆ id        ┆ id        ┆ e         ┆   ┆ ---       ┆ on        ┆ al_code   ┆ try       │
# │ i16      ┆ ---       ┆ ---       ┆ ---       ┆   ┆ str       ┆ ---       ┆ ---       ┆ ---       │
# │          ┆ str       ┆ i16       ┆ date      ┆   ┆           ┆ str       ┆ str       ┆ str       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 10248    ┆ VINET     ┆ 5         ┆ 1996-07-0 ┆ … ┆ Reims     ┆ null      ┆ 51100     ┆ France    │
# │          ┆           ┆           ┆ 4         ┆   ┆           ┆           ┆           ┆           │
# │ 10249    ┆ TOMSP     ┆ 6         ┆ 1996-07-0 ┆ … ┆ Münster   ┆ null      ┆ 44087     ┆ Germany   │
# ...

# %%
q1 = (
    read_north
    .with_columns(pl.col("ship_name").str.to_uppercase())
)
q1
# Out:
# shape: (830, 14)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ order_id ┆ customer_ ┆ employee_ ┆ order_dat ┆ … ┆ ship_city ┆ ship_regi ┆ ship_post ┆ ship_coun │
# │ ---      ┆ id        ┆ id        ┆ e         ┆   ┆ ---       ┆ on        ┆ al_code   ┆ try       │
# │ i16      ┆ ---       ┆ ---       ┆ ---       ┆   ┆ str       ┆ ---       ┆ ---       ┆ ---       │
# │          ┆ str       ┆ i16       ┆ date      ┆   ┆           ┆ str       ┆ str       ┆ str       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 10248    ┆ VINET     ┆ 5         ┆ 1996-07-0 ┆ … ┆ Reims     ┆ null      ┆ 51100     ┆ France    │
# │          ┆           ┆           ┆ 4         ┆   ┆           ┆           ┆           ┆           │
# │ 10249    ┆ TOMSP     ┆ 6         ┆ 1996-07-0 ┆ … ┆ Münster   ┆ null      ┆ 44087     ┆ Germany   │
# ...

# %%
lf_analytics = (
    pl.read_database_uri(query="SELECT * FROM order_details", uri="postgresql://neondb_owner:npg_X9yglTDSNqI7@ep-fancy-morning-ayjb5nrr-pooler.c-5.us-east-2.aws.neon.tech/neondb?sslmode=require&channel_binding=require")
    .lazy()  
    .filter(pl.col("discount") > 0.1)
    .group_by("product_id")
    .agg(pl.col("quantity").sum())
)

# Execute the final optimized plan
df_result = lf_analytics.collect()
df_result
# Out:
# shape: (74, 2)
# ┌────────────┬──────────┐
# │ product_id ┆ quantity │
# │ ---        ┆ ---      │
# │ i16        ┆ i64      │
# ╞════════════╪══════════╡
# │ 49         ┆ 45       │
# │ 52         ┆ 96       │
# │ 31         ┆ 427      │
# │ 77         ┆ 117      │
# │ 62         ┆ 219      │
# │ …          ┆ …        │
# │ 14         ┆ 123      │
# │ 25         ┆ 90       │
# │ 24         ┆ 239      │
# │ 43         ┆ 165      │
# │ 56         ┆ 289      │
# └────────────┴──────────┘

# %%
df_large_orders = pl.read_database_uri(
    query="SELECT * FROM orders",
    uri=uri_north,
)
# df_large_orders = df_large_orders.filter(pl.col("freight") > 100)
df_large_orders
# Out:
# shape: (830, 14)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ order_id ┆ customer_ ┆ employee_ ┆ order_dat ┆ … ┆ ship_city ┆ ship_regi ┆ ship_post ┆ ship_coun │
# │ ---      ┆ id        ┆ id        ┆ e         ┆   ┆ ---       ┆ on        ┆ al_code   ┆ try       │
# │ i16      ┆ ---       ┆ ---       ┆ ---       ┆   ┆ str       ┆ ---       ┆ ---       ┆ ---       │
# │          ┆ str       ┆ i16       ┆ date      ┆   ┆           ┆ str       ┆ str       ┆ str       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 10248    ┆ VINET     ┆ 5         ┆ 1996-07-0 ┆ … ┆ Reims     ┆ null      ┆ 51100     ┆ France    │
# │          ┆           ┆           ┆ 4         ┆   ┆           ┆           ┆           ┆           │
# │ 10249    ┆ TOMSP     ┆ 6         ┆ 1996-07-0 ┆ … ┆ Münster   ┆ null      ┆ 44087     ┆ Germany   │
# ...

# %% [markdown]
# ### Query 1: Top 5 VIP Customers by Revenue (Including Discounts)

# %%
df_top_customers_revenue = pl.read_database_uri(
    query="""WITH CustomerRevenue AS (
    SELECT 
        c.customer_id,
        c.company_name,
        c.country,
        ROUND(SUM(od.unit_price * od.quantity * (1 - od.discount))::numeric, 2) AS total_spent
    FROM customers c
    JOIN orders o ON c.customer_id = o.customer_id
    JOIN order_details od ON o.order_id = od.order_id
    GROUP BY c.customer_id, c.company_name, c.country
)
SELECT customer_id, company_name, country, total_spent
FROM CustomerRevenue
ORDER BY total_spent DESC
LIMIT 5;""",
    uri=uri_north,
)
df_top_customers_revenue
# Out:
# shape: (5, 4)
# ┌─────────────┬──────────────────────────────┬─────────┬───────────────────┐
# │ customer_id ┆ company_name                 ┆ country ┆ total_spent       │
# │ ---         ┆ ---                          ┆ ---     ┆ ---               │
# │ str         ┆ str                          ┆ str     ┆ decimal[38,10]    │
# ╞═════════════╪══════════════════════════════╪═════════╪═══════════════════╡
# │ QUICK       ┆ QUICK-Stop                   ┆ Germany ┆ 110277.3100000000 │
# │ ERNSH       ┆ Ernst Handel                 ┆ Austria ┆ 104874.9800000000 │
# │ SAVEA       ┆ Save-a-lot Markets           ┆ USA     ┆ 104361.9500000000 │
# │ RATTC       ┆ Rattlesnake Canyon Grocery   ┆ USA     ┆ 51097.8000000000  │
# │ HUNGO       ┆ Hungry Owl All-Night Grocers ┆ Ireland ┆ 49979.9100000000  │
# └─────────────┴──────────────────────────────┴─────────┴───────────────────┘

# %% [markdown]
# ### Query 2: Product Performance & Reorder Risk Matrix

# %%
df_product_performance = pl.read_database_uri(
    query="""SELECT 
    p.product_id,
    p.product_name,
    cat.category_name,
    p.units_in_stock,
    p.reorder_level,
    CASE 
        WHEN p.units_in_stock = 0 THEN 'OUT OF STOCK'
        WHEN p.units_in_stock <= p.reorder_level THEN 'REORDER NOW'
        ELSE 'OK'
    END AS stock_status
FROM products p
JOIN categories cat ON p.category_id = cat.category_id
WHERE p.discontinued = 0
ORDER BY p.units_in_stock ASC;""",
    uri=uri_north,
)
df_product_performance
# df_product_ok = df_product_performance.filter(pl.col("stock_status") > 'OK')
# df_product_ok
# Out:
# shape: (67, 6)
# ┌────────────┬────────────────────┬────────────────┬────────────────┬───────────────┬──────────────┐
# │ product_id ┆ product_name       ┆ category_name  ┆ units_in_stock ┆ reorder_level ┆ stock_status │
# │ ---        ┆ ---                ┆ ---            ┆ ---            ┆ ---           ┆ ---          │
# │ i16        ┆ str                ┆ str            ┆ i16            ┆ i16           ┆ str          │
# ╞════════════╪════════════════════╪════════════════╪════════════════╪═══════════════╪══════════════╡
# │ 31         ┆ Gorgonzola Telino  ┆ Dairy Products ┆ 0              ┆ 20            ┆ OUT OF STOCK │
# │ 21         ┆ Sir Rodney's       ┆ Confections    ┆ 3              ┆ 5             ┆ REORDER NOW  │
# │            ┆ Scones             ┆                ┆                ┆               ┆              │
# │ 66         ┆ Louisiana Hot      ┆ Condiments     ┆ 4              ┆ 20            ┆ REORDER NOW  │
# ...

# %% [markdown]
# ### Query 4: Monthly Revenue Growth & Moving Averages

# %%
growth_query = pl.read_database_uri(
    query="""WITH MonthlySales AS (
    SELECT 
        DATE_TRUNC('month', o.order_date)::date AS order_month,
        SUM(od.unit_price * od.quantity * (1 - od.discount)) AS monthly_revenue
    FROM orders o
    JOIN order_details od ON o.order_id = od.order_id
    GROUP BY DATE_TRUNC('month', o.order_date)
)
SELECT 
    order_month,
    ROUND(monthly_revenue::numeric, 2) AS current_month_revenue,
    ROUND(LAG(monthly_revenue, 1) OVER (ORDER BY order_month)::numeric, 2) AS prior_month_revenue,
    ROUND((
        (monthly_revenue - LAG(monthly_revenue, 1) OVER (ORDER BY order_month)) 
        / LAG(monthly_revenue, 1) OVER (ORDER BY order_month) * 100
    )::numeric, 2) AS mom_growth_pct,
    ROUND(AVG(monthly_revenue) OVER(
        ORDER BY order_month 
        ROWS BETWEEN 2 PRECEDING AND CURRENT ROW
    )::numeric, 2) AS rolling_3_month_avg
FROM MonthlySales
ORDER BY order_month;""",
    uri=uri_north,
)
growth_query
# Out:
# shape: (23, 5)
# ┌─────────────┬───────────────────────┬─────────────────────┬────────────────┬─────────────────────┐
# │ order_month ┆ current_month_revenue ┆ prior_month_revenue ┆ mom_growth_pct ┆ rolling_3_month_avg │
# │ ---         ┆ ---                   ┆ ---                 ┆ ---            ┆ ---                 │
# │ date        ┆ decimal[38,10]        ┆ decimal[38,10]      ┆ decimal[38,10] ┆ decimal[38,10]      │
# ╞═════════════╪═══════════════════════╪═════════════════════╪════════════════╪═════════════════════╡
# │ 1996-07-01  ┆ 27861.9000000000      ┆ null                ┆ null           ┆ 27861.9000000000    │
# │ 1996-08-01  ┆ 25485.2800000000      ┆ 27861.9000000000    ┆ -8.5300000000  ┆ 26673.5900000000    │
# │ 1996-09-01  ┆ 26381.4000000000      ┆ 25485.2800000000    ┆ 3.5200000000   ┆ 26576.1900000000    │
# │ 1996-10-01  ┆ 37515.7200000000      ┆ 26381.4000000000    ┆ 42.2100000000  ┆ 29794.1300000000    │
# ...
